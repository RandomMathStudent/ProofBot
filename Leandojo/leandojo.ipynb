# %%
import os
print(os.environ.get("GITHUB_ACCESS_TOKEN"))
# Out:
# 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

# %%
from lean_dojo_v2.agent.hf_agent import HFAgent
from lean_dojo_v2.trainer.sft_trainer import SFTTrainer

url = "https://github.com/durant42040/lean4-example"
commit = "005de00d03f1aaa32cb2923d5e3cbaf0b954a192"

trainer = SFTTrainer(
    model_name="deepseek-ai/DeepSeek-Prover-V2-7B",
    output_dir="outputs-deepseek",
    epochs_per_repo=1,
    batch_size=2,
    lr=2e-5,
    use_cpu = True
)

agent = HFAgent(trainer=trainer)
agent.setup_github_repository(url=url, commit=commit)
agent.train()
agent.prove()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 7
#       4 url = "https://github.com/durant42040/lean4-example"
#       5 commit = "005de00d03f1aaa32cb2923d5e3cbaf0b954a192"
# ----> 7 trainer = SFTTrainer(
#       8     model_name="deepseek-ai/DeepSeek-Prover-V2-7B",
#       9     output_dir="outputs-deepseek",
#      10     epochs_per_repo=1,
#      11     batch_size=2,
#      12     lr=2e-5,
#      13     use_cpu = True
#      14 )
#      16 agent = HFAgent(trainer=trainer)
#      17 agent.setup_github_repository(url=url, commit=commit)
#
# TypeError: SFTTrainer.__init__() got an unexpected keyword argument 'use_cpu'
